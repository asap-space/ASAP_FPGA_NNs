# %%
import torch
import torch.nn as nn
from CNetPlusScalar import CNetPlusScalar

# %%
model = CNetPlusScalar()
model.load_state_dict(torch.load('model.pth'))
# Save the model pre-trained weights
torch.save(model.state_dict(), 'pre_trained_w.pt')
# Out:
# odict_keys(['conv1.weight', 'conv1.bias', 'conv2.weight', 'conv2.bias', 'conv3.weight', 'conv3.bias', 'conv4.weight', 'conv4.bias', 'fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'fc3.weight', 'fc3.bias'])

# %%
dummy_input_img = torch.rand((1, 1, 512, 512), dtype=torch.float32)
dummy_input_scalar = torch.rand((1, 1), dtype=torch.float32)
torch.onnx.export(
    model,
    (dummy_input_img, dummy_input_scalar, ),
    "CNetPlusScalar.onnx",  # filename of the ONNX model
    input_names=["input_img", "input_scalar"],  # Rename inputs for the ONNX model
    output_names=["output"],  # Rename outputs for the ONNX model
    dynamo=False,  # True or False to select the exporter to use
)

# %%
# Generate random test inputs
num_samples = 100
dataset = torch.rand((1, 1, 512, 512), dtype=torch.float32)

# %%
# WIP
model.eval() 

with torch.no_grad():
    scalar = torch.zeros((1, 1), dtype=torch.float32)
    for image in dataset:
        scalar = model(image, scalar.reshape((1,1)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 7
#       5 scalar = torch.zeros((1, 1), dtype=torch.float32)
#       6 for image in dataset:
# ----> 7     scalar = model(image, scalar.reshape((1,1)))
#
# File ~/Documents/PhD/Research/ONNX2FPGA/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PhD/Research/ONNX2FPGA/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/PhD/Research/ONNX2FPGA/Common/CNet/CNetPlusScalar.py:30, in CNetPlusScalar.forward(self, image, scalar)
#      28 x = self.pool(F.relu(self.conv4(x)))
#      29 x = torch.flatten(x, 1) # flatten all dimensions except batch
# ---> 30 x = F.relu(self.fc1(x))
#      31 x = F.relu(self.fc2(x))
#      32 x = torch.cat((x, scalar), dim=1) # adding the scalar value
#
# File ~/Documents/PhD/Research/ONNX2FPGA/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PhD/Research/ONNX2FPGA/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/PhD/Research/ONNX2FPGA/.venv/lib/python3.9/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (32x784 and 25088x120)
