# %%
import torch
import sys

COMMON_PATH = "../../Common/MMSNet"
sys.path.append(COMMON_PATH)
try:
	from MMSNet import LogisticNet, ReducedNet, BaselineNet
except ModuleNotFoundError as e:
	print(f"Error: Could not import MMSNet modules. Check COMMON_PATH: {COMMON_PATH}")
	raise e

# %%
model = LogisticNet()
model.load_state_dict(torch.load(f'{COMMON_PATH}/PreTrained_Weights/LogisticNet_84.pth', weights_only=True))
# Out:
# <All keys matched successfully>

# %%
import hls4ml
config = hls4ml.utils.config_from_pytorch_model(
     model,
     granularity='name',
     default_precision='fixed<16,6>',
     backend='Vitis')
# Out:
# /Users/pantunes/Documents/PhD/Research/ONNX2FPGA/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
print(config)
# Out:
# {'Model': {'Precision': 'fixed<16,6>', 'ReuseFactor': 1, 'InputsChannelLast': False, 'TransposeOutputs': True, 'Strategy': 'Latency'}}

# %%
hls_model = hls4ml.converters.convert_from_pytorch_model(
      model,
      hls_config=config,
      output_dir="my_project_dir",
      io_type='io_stream',
      backend='Vitis',
      input_shape=(1, 1, 32, 16, 32),
  )
# Out:
# Interpreting Model ...
# Topology:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 hls_model = hls4ml.converters.convert_from_pytorch_model(
#       2       model,
#       3       hls_config=config,
#       4       output_dir="my_project_dir",
#       5       io_type='io_stream',
#       6       backend='Vitis',
#       7       input_shape=(1, 1, 32, 16, 32),
#       8   )
#
# File ~/Documents/PhD/Research/ONNX2FPGA/.venv/lib/python3.9/site-packages/hls4ml/converters/__init__.py:305, in convert_from_pytorch_model(model, input_shape, output_dir, project_name, input_data_tb, output_data_tb, backend, hls_config, **kwargs)
#     301 config['HLSConfig']['Model'] = _check_model_config(model_config)
#     303 _check_hls_config(config, hls_config)
# --> 305 return pytorch_to_hls(config)
#
# File ~/Documents/PhD/Research/ONNX2FPGA/.venv/lib/python3.9/site-packages/hls4ml/converters/pytorch_to_hls.py:175, in pytorch_to_hls(config)
#     172 pytorch_class = class_object.__class__.__name__
#     174 if pytorch_class not in supported_layers:
# --> 175     raise Exception(f'Unsupported layer {pytorch_class}')
#     177 if layer_counter != 0:
#     178     input_shapes = [output_shape]  # In case there are multiple inputs
#
# Exception: Unsupported layer MaxPool3d
